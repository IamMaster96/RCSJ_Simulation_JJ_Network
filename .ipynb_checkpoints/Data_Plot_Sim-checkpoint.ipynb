# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.ndimage import gaussian_filter

from ipywidgets import interact,interactive,fixed,interact_manual
import ipywidgets as widgets

# %%
plt.rcParams['text.usetex'] = True 
plt.rcParams['text.latex.preamble'] = r"\usepackage{bm} \usepackage{amsmath} \usepackage[cm]{sfmath}"
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'cm'
plt.rcParams.update({'font.size': 20})

# %%
def create_XY(xcol,ycol):
    meshx=data[:,xcol].reshape(rpoints,cpoints)
    meshy=data[:,ycol].reshape(rpoints,cpoints)
    return meshx,meshy

# %%
def create_cdXY(xcol,ycol):
    meshx,meshy=create_XY(xcol,ycol)
    return meshx[:,0:cpoints-1],meshy[:,0:cpoints-1]
def create_rdXY(xcol,ycol):
    meshx,meshy=create_XY(xcol,ycol)
    return meshx[0:rpoints-1,:],meshy[0:rpoints-1,:]

# %%
def plot_2dx(xcol,ycol,xc_col,yc_col,cticks,lwr,upr,mar_type=0,flag=1,clable='',lfilter=0,ylim=[0,0],xlim=[0,0],nmar=[],delta=0,axis=1):
    X,Y=create_cdXY(xcol,ycol)
    
    data_y=data[:,yc_col].reshape(rpoints,cpoints)
    data_x=data[:,xc_col].reshape(rpoints,cpoints)
    
    if(axis==1):
        rd=0
        cd=1
        X,Y=create_cdXY(xcol,ycol)
    else:
        rd=1
        cd=0
        X,Y=create_rdXY(xcol,ycol)
    data_z=(np.diff(data_y,axis=axis)/np.diff(data_x,axis=axis)).reshape(rpoints-rd,cpoints-cd)
    data_z=abs(gaussian_filter(data_z,sigma=lfilter))
    
    mean_data=np.mean(data_z)
    max_data=1.5*mean_data
    
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    
    g = plt.contourf(X,Y,data_z,np.linspace(lwr,upr,100), cmap='seismic',extend='both',zorder=-2)
    plt.gca().set_rasterization_zorder(-1)


    cb = plt.colorbar(g,ticks=cticks)
    cb.ax.set_title(clable, size =20 )
    if(flag==0):
        delta=2*delta
        datav1=data[:,4].reshape(rpoints,cpoints)
        datav2=data[:,5].reshape(rpoints,cpoints)
        for ki in range(len(nmar)):
            i_ar=[]
            j_ar=[]
            iq_ar=[]
            jq_ar=[]
            for i in range(rpoints):
                for j in range(cpoints):
                    v1=datav1[i,j]
                    v2=datav2[i,j]
                    if(mar_type==2):
                        if (delta/nmar[ki]-1<(v1-v2)<delta/nmar[ki]+1):
                            i_ar.append(i)
                            j_ar.append(j)
                        if (delta/nmar[ki]-1<(v1)<delta/nmar[ki]+1):
                            i_ar.append(i)
                            j_ar.append(j)

                        if(abs(v1)>50 and abs(v2)>50):
                            if (v2-.1<-v1<v2+.1):
                                iq_ar.append(i)
                                jq_ar.append(j)

            i1=data[:,4].reshape(rpoints,cpoints)
            i2=data[:,5].reshape(rpoints,cpoints)
            plt.plot(i1[i_ar,j_ar],i2[i_ar,j_ar],'.g',axes=ax,markersize=0.5)
            plt.plot(i1[iq_ar,jq_ar],i2[iq_ar,jq_ar],'--g',linestyle='--', dashes=(5, 10),axes=ax,markersize=0.5)
    ax.set_aspect(1.0)
    return g

# %%
data=np.loadtxt('IV_Char.txt')
scaling=np.array([1*1e3,1*1e3,1e3,1e3])
for i in range(4):
    data[:,i]=scaling[i]*data[:,i]

# %%
cpoints=100
rpoints=100

# %%
plot_2dx(0,1,1,3,axis=0,lwr=0,upr=500,cticks=(0,150,300,450),clable=r'${dV_1/dI_1 (\Omega)}$',flag=1,nmar=[2,4,6],mar_type=2,delta=145,lfilter=1)
plt.xlabel(r'${I_1}$ ($\mu$A)',fontsize=20)
plt.ylabel(r'${I_2}$ ($\mu$A)',fontsize=20)
plt.xticks(ticks=(-0.8,-0.4,0,0.4,0.8), fontsize=20)
plt.yticks(ticks=(-0.8,-0.4,0,0.4,0.8), fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-350f683f659f> in <module>
# ----> 1 plot_2dx(0,1,1,3,axis=0,lwr=0,upr=500,cticks=(0,150,300,450),clable=r'${dV_1/dI_1 (\Omega)}$',flag=1,nmar=[2,4,6],mar_type=2,delta=145,lfilter=1)
#       2 plt.xlabel(r'${I_1}$ ($\mu$A)',fontsize=20)
#       3 plt.ylabel(r'${I_2}$ ($\mu$A)',fontsize=20)
#       4 plt.xticks(ticks=(-0.8,-0.4,0,0.4,0.8), fontsize=20)
#       5 plt.yticks(ticks=(-0.8,-0.4,0,0.4,0.8), fontsize=20)
#
# <ipython-input-5-e2bc3740c397> in plot_2dx(xcol, ycol, xc_col, yc_col, cticks, lwr, upr, mar_type, flag, clable, lfilter, ylim, xlim, nmar, delta, axis)
#       1 def plot_2dx(xcol,ycol,xc_col,yc_col,cticks,lwr,upr,mar_type=0,flag=1,clable='',lfilter=0,ylim=[0,0],xlim=[0,0],nmar=[],delta=0,axis=1):
# ----> 2     X,Y=create_cdXY(xcol,ycol)
#       3
#       4     data_y=data[:,yc_col].reshape(rpoints,cpoints)
#       5     data_x=data[:,xc_col].reshape(rpoints,cpoints)
#
# <ipython-input-4-8cee2c6388a8> in create_cdXY(xcol, ycol)
#       1 def create_cdXY(xcol,ycol):
# ----> 2     meshx,meshy=create_XY(xcol,ycol)
#       3     return meshx[:,0:cpoints-1],meshy[:,0:cpoints-1]
#       4 def create_rdXY(xcol,ycol):
#       5     meshx,meshy=create_XY(xcol,ycol)
#
# <ipython-input-3-eb7b0b5b1d10> in create_XY(xcol, ycol)
#       1 def create_XY(xcol,ycol):
# ----> 2     meshx=data[:,xcol].reshape(rpoints,cpoints)
#       3     meshy=data[:,ycol].reshape(rpoints,cpoints)
#       4     return meshx,meshy
#
# ValueError: cannot reshape array of size 9999 into shape (100,100)

# %%
data=np.loadtxt('device_2_R1_Vg5V_12_6V.dat')
scaling=np.array([1*1e-3,1*1e-3,0,0,1e-2*1e6,1e-2*1e6,0,0,0])
for i in range(9):
    data[:,i]=scaling[i]*data[:,i]

# %%
cpoints=251
rpoints=251

# %%
plot_2dx(0,1,0,4,lwr=0,upr=500,cticks=(0,150,300,450),clable=r'${dV_1/dI_1 (\Omega)}$',flag=1,nmar=[2,4,6],mar_type=2,delta=145,lfilter=1,axis=1)
plt.xlabel(r'${I_1}$ ($\mu$A)',fontsize=20)
plt.ylabel(r'${I_2}$ ($\mu$A)',fontsize=20)
plt.xticks(ticks=(-0.8,-0.4,0,0.4,0.8), fontsize=20)
plt.yticks(ticks=(-0.8,-0.4,0,0.4,0.8), fontsize=20)
#plt.ylim(-100,100)
#plt.xlim(-100,100)
plt.savefig('../Figures/device_2_iv_1_5V_12_6V.svg',dpi=100,bbox_inches='tight')

# %%
def plot_2dx(xcol,ycol,xc_col,yc_col,lwr,upr,mar_type=0,flag=1,clable='',lfilter=0,ylim=[0,0],xlim=[0,0],nmar=[],delta=0,axis=1):
    X,Y=create_cdXY(xcol,ycol)
    
    data_y=data[:,yc_col].reshape(rpoints,cpoints)
    data_x=data[:,xc_col].reshape(rpoints,cpoints)
    
    if(axis==1):
        rd=0
        cd=1
        X,Y=create_cdXY(xcol,ycol)
    else:
        rd=1
        cd=0
        X,Y=create_rdXY(xcol,ycol)
    data_z=(np.diff(data_y,axis=axis)/np.diff(data_x,axis=axis)).reshape(rpoints-rd,cpoints-cd)
    data_z=abs(gaussian_filter(data_z,sigma=lfilter))
    
    mean_data=np.mean(data_z)
    max_data=1.5*mean_data
    
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    
    g = plt.contourf(X,Y,data_z,np.linspace(lwr,upr,100), cmap='seismic',extend='both',zorder=-2)
    plt.gca().set_rasterization_zorder(-1)


    cb = plt.colorbar(g,ticks=(0,20,40,60,80,100))
    cb.ax.set_title(clable, size = 20)
    if(flag==0):
        delta=2*delta
        datav1=data[:,4].reshape(rpoints,cpoints)
        datav2=data[:,5].reshape(rpoints,cpoints)
        for ki in range(len(nmar)):
            i_ar=[]
            j_ar=[]
            iq_ar=[]
            jq_ar=[]
            for i in range(rpoints):
                for j in range(cpoints):
                    v1=datav1[i,j]
                    v2=datav2[i,j]
                    if(mar_type==2):
#                         if (delta/nmar[ki]-1<(v1-v2)<delta/nmar[ki]+1):
#                             i_ar.append(i)
#                             j_ar.append(j)
                        if (delta/nmar[ki]-1<(v1)<delta/nmar[ki]+1):
                            i_ar.append(i)
                            j_ar.append(j)

                        if(abs(v1)>50 and abs(v2)>50):
                            if (v2-.1<-v1<v2+.1):
                                iq_ar.append(i)
                                jq_ar.append(j)

            i1=data[:,4].reshape(rpoints,cpoints)
            i2=data[:,5].reshape(rpoints,cpoints)
            plt.plot(i1[i_ar,j_ar],i2[i_ar,j_ar],'.g',axes=ax,markersize=0.5)
            plt.plot(i1[iq_ar,jq_ar],i2[iq_ar,jq_ar],'--g',linestyle='--', dashes=(5, 10),axes=ax,markersize=0.5)
    ax.set_aspect(1.0)
    return g

# %%
data=np.loadtxt('device_1_R1.dat')
scaling=np.array([10*1e-3,10*1e-3,0,0,1e-2*1e6,1e-2*1e6,0,0,0])
for i in range(9):
    data[:,i]=scaling[i]*data[:,i]

# %%
cpoints=501
rpoints=501

# %%
plot_2dx(4,5,0,4,lwr=0,upr=100,clable=r'${dV_1/dI_1 (\Omega)}$',flag=1,nmar=[2,4,6,8],mar_type=2,delta=150,lfilter=1,axis=1)
plt.xlabel(r'${V_1}$ ($\mu$V)',fontsize=20)
plt.ylabel(r'${V_2}$ ($\mu$V)',fontsize=20)
#plt.xticks(ticks=(-4,-2,0,2,4),fontsize=20)
#plt.yticks(ticks=(-4,-2,0,2,4),fontsize=20)
plt.ylim(-95,95)
plt.xlim(-95,95)
plt.savefig('../Figures/device_1_iv_1_Vspace.svg',dpi=100,bbox_inches='tight')
